# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaryant74/Data_Science_Assignments/blob/main/3_BASIC_STATISTICS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset**
#
# * To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.

# %% [markdown]
# **Descriptive Analytics for Numerical Columns**
#
# 1. Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
#
# 2. Steps:
#
# * Load the dataset into a data analysis tool or programming environment (e.g.,Python with pandas library).
# * Identify numerical columns in the dataset.
# * Calculate the mean, median, mode, and standard deviation for these columns.
# * Provide a brief interpretation of these statistics.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/content/sales_data_with_discounts.csv')

# Select numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64'])

print("Numerical Columns:")
print(num_cols.columns)

# Calculate statistics
stats = pd.DataFrame({
    'Mean': num_cols.mean(),
    'Median': num_cols.median(),
    'Mode': num_cols.mode().iloc[0],
    'Standard Deviation': num_cols.std()
})

print("\nStatistical Summary:\n", stats)

# Brief Interpretation:

# Mean shows the average values of sales, discount, and profit.
# Median shows the middle value and is not affected by very high or low values.
# Mode shows the most common value.
# Standard deviation shows how much the data changes: Sales and profit change more (high variation), Discount changes less (low variation).

# %% [markdown]
# **Data Visualization**
#
# Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
#
# * **Histograms:** Plot histograms for each numerical column.
# Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.
#
# * **Box Plots:** Create boxplots for numerical variables to identify outliers and the interquartile range.
# Discuss any findings, such as extreme values or unusual distributions.
#
# * **Bar Chart Analysis for Categorical Column:** Identify categorical columns in the dataset.
# Create bar charts to visualize the frequency or count of each category.
# Analyze the distribution of categories and provide insights.

# %% [markdown]
# **1. Histogram**

# %%
import matplotlib.pyplot as plt

# Select numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64'])

# Plot histograms
num_cols.hist(figsize=(12, 8))
plt.suptitle("Histograms of Numerical Columns")
plt.show()

# Distribution Analysis:

# If the graph is symmetric - data is normally distributed
# If it is right-skewed - more smaller values, few large values
# If it is left-skewed - more larger values, few small values
# If there are extreme bars far away - outliers are present

# Inference (Simple):

# Sales and Profit may be right-skewed → few very high values
# Discount is usually normally distributed or slightly skewed
# Presence of outliers shows unusual high or low values in data

# %% [markdown]
# **2. Box Plot**

# %%
# Select numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64'])

# Create boxplots
plt.figure(figsize=(12, 6))
num_cols.boxplot()
plt.title("Boxplots of Numerical Columns")
plt.xticks(rotation=45)
plt.show()

# Findings:

# Sales and Profit may have outliers, showing some very high or low values.
# Discount usually has less variation and fewer outliers.
# If the box is not centered → data is skewed.

# %% [markdown]
# **3. Bar Chart Analysis for Categorical Column**

# %%
# Identifying categorical columns
cat_cols = df.select_dtypes(include=['object'])

print("Categorical Columns:\n", cat_cols.columns)

# Plot bar charts for each category
for col in cat_cols.columns:
    plt.figure()
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Bar Chart of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

# Bar Chart Analysis: Bar charts show how frequently each category appears.
                      # Taller bars indicate more common categories.

#Insights: Some categories have higher frequency, meaning they occur more often.
           # Some categories have low frequency, meaning they are less common.
           # Uneven bar heights showing an imbalanced distribution of categories.

# %% [markdown]
# **Conclusion:**
#
# The dataset was analyzed using descriptive statistics and visualizations. The numerical data showed average values, variation, and some outliers, especially in sales and profit.
#
#
# Histograms and boxplots helped identify data distribution and extreme values. Bar charts showed how different categories are distributed, with some categories appearing more frequently than others. Overall, the analysis helped in understanding the data patterns, variation, and important insights.
